# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
single_laplacian = pd.read_csv('test_metrics_single_laplacian_gudhi_medical.csv')
dual_abstract = pd.read_csv('test_metrics_dual_lap_abstract_gudhi_medical.csv')
dual_vr = pd.read_csv('test_metrics_dual_lap_vr_gudhi_medical.csv')

# %%
single_laplacian
dual_abstract
dual_vr
# Out:
#    Epoch  Test Loss  Test Accuracy  Precision    Recall  F1 Score  Train Loss  \
# 0      1   0.078643       0.818505   0.716763  0.984127  0.829431    0.965496
# 1      2   0.052408       0.811388   0.713450  0.968254  0.821549    0.002843
# 2      3   0.043413       0.818505   0.721893  0.968254  0.827119    0.001655
# 3      4   0.034799       0.829181   0.737805  0.960317  0.834483    0.001279
# 4      5   0.036463       0.825623   0.736196  0.952381  0.830450    0.000715
# 5      6   0.031892       0.818505   0.738854  0.920635  0.819788    0.003210
# 6      7   0.038243       0.811388   0.715976  0.960317  0.820339    0.003918
# 7      8   0.037938       0.818505   0.735849  0.928571  0.821053    0.001140
# 8      9   0.048668       0.829181   0.737805  0.960317  0.834483    0.000735
# 9     10   0.062459       0.807829   0.706897  0.976190  0.820000    0.000959
#
#    Train Accuracy  Valid Loss  Valid Accuracy
# 0        0.856875    2.129993        0.832740
# 1        0.983750    1.320240        0.829181
# 2        0.988750    1.054949        0.829181
# 3        0.985625    0.764594        0.843416
# 4        0.990625    0.800424        0.839858
# 5        0.981875    0.541957        0.861210
# 6        0.971875    0.873151        0.836299
# 7        0.986250    0.814926        0.843416
# 8        0.993750    1.123557        0.839858
# 9        0.992500    1.570964        0.829181

# %%
single_laplacian['Dataset'] = "Single Laplacian"
dual_abstract['Dataset'] = "Dual Laplacian + Abstract"
dual_vr['Dataset'] = "Dual Laplacian + VR"
combined_data = pd.concat([single_laplacian, dual_abstract, dual_vr])
metric_to_plot = "Test Loss"

# %%
plt.figure(figsize=(10,6))
for labels, group in combined_data.groupby('Dataset'):
    plt.plot(group['Epoch'], group[metric_to_plot], label=labels)

plt.title(f"Epoch vs {metric_to_plot}", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel(metric_to_plot, fontsize=12)
plt.legend(title="Dataset", fontsize=10)
plt.grid(alpha=0.5)
plt.show()
