# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
single_laplacian = pd.read_csv('test_metrics_single_laplacian_gudhi_medical.csv')
dual_abstract = pd.read_csv('test_metrics_dual_lap_abstract_gudhi_medical.csv')
dual_vr = pd.read_csv('test_metrics_dual_lap_vr_gudhi_medical.csv')

# %%
single_laplacian
dual_abstract
dual_vr
# Out:
#    Epoch  Test Loss  Test Accuracy  Precision    Recall  F1 Score  Train Loss  \
# 0      1   0.030252       0.765125   0.691824  0.866142  0.769231    1.104280
# 1      2   0.041327       0.804270   0.702247  0.984252  0.819672    0.002556
# 2      3   0.057844       0.807829   0.703911  0.992126  0.823529    0.001015
# 3      4   0.056266       0.811388   0.707865  0.992126  0.826230    0.000854
# 4      5   0.060835       0.811388   0.707865  0.992126  0.826230    0.000628
# 5      6   0.054878       0.811388   0.707865  0.992126  0.826230    0.000526
# 6      7   0.049105       0.811388   0.707865  0.992126  0.826230    0.000704
# 7      8   0.058549       0.807829   0.706215  0.984252  0.822368    0.000449
# 8      9   0.053920       0.804270   0.704545  0.976378  0.818482    0.000335
# 9     10   0.045564       0.814947   0.721893  0.960630  0.824324    0.001329
#
#    Train Accuracy  Valid Loss  Valid Accuracy
# 0        0.786250    1.041719        0.779359
# 1        0.966875    1.519208        0.786477
# 2        0.988125    2.134710        0.786477
# 3        0.985625    2.076968        0.786477
# 4        0.996250    2.234334        0.786477
# 5        0.991875    2.013819        0.786477
# 6        0.986250    1.825862        0.786477
# 7        0.991875    2.175213        0.786477
# 8        0.995625    1.995662        0.786477
# 9        0.978750    1.711481        0.800712

# %%
single_laplacian['Dataset'] = "Single Laplacian"
dual_abstract['Dataset'] = "Dual Laplacian + Abstract"
dual_vr['Dataset'] = "Dual Laplacian + VR"
combined_data = pd.concat([single_laplacian, dual_abstract, dual_vr])
metric_to_plot = "Precision"

# %%
plt.figure(figsize=(10,6))
for labels, group in combined_data.groupby('Dataset'):
    plt.plot(group['Epoch'], group[metric_to_plot], label=labels)

plt.title(f"Epoch vs {metric_to_plot}", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel(metric_to_plot, fontsize=12)
plt.legend(title="Dataset", fontsize=10)
plt.grid(alpha=0.5)
plt.show()
